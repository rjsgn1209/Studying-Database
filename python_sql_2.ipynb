# %%
import MySQLdb
import pandas as pd

# %%
import MySQLdb
import pandas as pd

# %%
db = MySQLdb.connect(host='localhost', user='root', password='1234')
x

# %%
sql = 'show databases;'

pd.read_sql(sql, db)
# Out:
#              Database
# 0  information_schema
# 1           employees
# 2               mysql
# 3  performance_schema
# 4              sakila
# 5               sqldb
# 6                 sys
# 7             tabledb
# 8               world

# %%
sql = """
create database if not exists budongsan;
"""

cursor.execute(sql)
# Out:
# 1

# %%
sql = """
use budongsan;
"""

cursor.execute(sql)
# Out:
# 0

# %%
sql = """
create table if not exists provider (
provider_id int primary key,
name varchar(30)
)
"""

cursor.execute(sql)
# Out:
# 0

# %%
sql = """
insert into provider values(1, '우리부동산');
insert into provider values(2, '한마음부동산');
"""

cursor.execute(sql)
cursor.fetchall()
# Out:
# ()

# %%
sql = """
select * from provider;
"""

cursor.execute(sql)
cursor.fetchall()
# Out:
# ((1, '우리부동산'), (2, '한마음부동산'))

# %%
budongsan = pd.read_csv('budongsan.csv', index_col=0)
budongsan.head(2)
# Out:
#         매물번호           연락처             주소              부동산      보증금     월세
# 0  3467204.0  010-123-4567  서울시 강남구 역삼동 0  TODAY공인중개사(이인규)   1000.0  100.0
# 1  3150497.0  010-123-4567  서울시 강남구 역삼동 1  TODAY공인중개사(이인규)  11000.0   60.0

# %%
sql = """
create table agency (
    agency_id float primary key,
    phone char(13),
    address char(20),
    agency_nm varchar(50),
    deposit float,
    rent float
)
"""

cursor.execute(sql)
# Out:
# 0

# %%
for i in range(len(budongsan)):
    p_id = budongsan.iloc[i][0]
    pho = budongsan.iloc[i][1]
    add = budongsan.iloc[i][2]
    an = budongsan.iloc[i][3]
    de = budongsan.iloc[i][4]
    re = budongsan.iloc[i][5]
    
    sql = "insert ignore into agency values ('{}', '{}', '{}', '{}', '{}', '{}')";
    sql = sql.format(p_id, pho, add, an, de, re)
    
    cursor.execute(sql)

# %%
sql = 'select * from agency'

pd.read_sql(sql, db)
# Out:
#     agency_id         phone         address          agency_nm  deposit   rent
# 0   3103380.0  010-123-4567  서울시 강남구 역삼동 17    TODAY공인중개사(이인규)   5000.0   50.0
# 1   3150500.0  010-123-4567   서울시 강남구 역삼동 1    TODAY공인중개사(이인규)  11000.0   60.0
# 2   3181680.0  010-123-4567  서울시 강남구 역삼동 20    TODAY공인중개사(이인규)   5000.0   60.0
# 3   3190410.0  010-123-4567  서울시 강남구 역삼동 28       건우공인중개사(김상모)     70.0   70.0
# 4   3228630.0  010-123-4567  서울시 강남구 역삼동 10     HS강남공인중개사(김현수)   1000.0   96.0
# 5   3249400.0  010-123-4567  서울시 강남구 역삼동 12       도원공인중개사(손석진)     65.0   65.0
# 6   3262170.0  010-123-4567   서울시 강남구 역삼동 9       스타공인중개사(박정직)   2000.0   50.0
# 7   3303060.0  010-123-4567   서울시 강남구 역삼동 8       동하공인중개사(임성우)   1000.0   60.0
# 8   3309370.0  010-123-4567  서울시 강남구 역삼동 21    한백부동산공인중개사(김남조)     75.0   75.0
# 9   3317230.0  010-123-4567  서울시 강남구 역삼동 15      커피한잔공인중개사(손별)    500.0   67.0
# 10  3322860.0  010-123-4567   서울시 강남구 역삼동 7       한강공인중개사(김상헌)   1000.0   80.0
# 11  3330750.0  010-123-4567  서울시 강남구 역삼동 38       미래공인중개사(김유철)   1000.0   85.0
# 12  3330950.0  010-123-4567  서울시 강남구 역삼동 13     강남우리공인중개사(어정화)   2000.0  150.0
