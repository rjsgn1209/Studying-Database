# %%
# 네이버 파이낸스 일별시세 스크롤링후 DB저장 - pandas.read_html()
# G마켓

# %%
#http://corners.gmarket.co.kr/Bestsellers

# %%
#categoryTabG > li.groupA.on

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import requests 
from bs4 import BeautifulSoup

# %%
url = 'http://corners.gmarket.co.kr/Bestsellers'

# %%
res = requests.get(url)
soup = BeautifulSoup(res.text, 'html.parser')

# %%
def sub_lis_extract(sub_lis, main_cate_title):
    for li in sub_lis:
        sub_cate_url = main_url + li['href']
        sub_cate_title = li.text
        print()
        print(f'( 서브 카테고리: {sub_cate_title} )')
        print()
        prod_path = '#gBestWrap > div > div:nth-child(5) > div:nth-child(3) > ul > li'

        res3 = requests.get(sub_cate_url)
        soup3 = BeautifulSoup(res3.text, 'html.parser')
        lis = soup3.select(prod_path)

        for li in lis[:5]:
            rank = li.select('p')[0].text
            prod_title = li.select('.itemname')[0].text
            old_price = li.select('.o-price')[0].text
            s_price = li.select('.s-price > strong > span')[0].text

            per = li.select('em')
            if per:
                s_per = per[0].text
            else:
                s_per = '0%'
            prod_url = li.select('div.thumb > a')[0]['href']

            # print(rank, prod_title, prod_url, old_price, s_price, s_per)
            # print("=" * 50)

# %%
dict_data = {}
rank_li = []
prod_title_li = []

# %%
main_url = 'http://corners.gmarket.co.kr/'
path = '#categoryTabG > li > a'
lis = soup.select(path)
for li in lis[:1]:
    main_cate_url = main_url + li['href']
    main_cate_title = li.text
    print(f'[ 메인 카테고리: {main_cate_title} ]')
    
    res1 = requests.get(main_cate_url)
    soup1 = BeautifulSoup(res1.text, 'html.parser')
    
    prod_path = '#gBestWrap > div > div:nth-child(5) > div:nth-child(3) > ul > li'
    sub_path = ".cate-l > div > ul > li > a"
    sub_lis = soup1.select(sub_path)
    
    if sub_lis:
        sub_lis_extract(sub_lis, main_cate_title)
    else:
        lis = soup1.select(prod_path)
        
        for li in lis[:5]:
            rank = li.select('p')[0].text
            prod_title = li.select('.itemname')[0].text
            old_price = li.select('.o-price')[0].text
            s_price = li.select('.s-price > strong > span')[0].text

            per = li.select('em')
            if per:
                s_per = per[0].text
            else:
                s_per = '0%'
                
            prod_url = li.select('div.thumb > a')[0]['href']
            
            rank_li.append(rank)
            # print(rank, prod_title, prod_url, old_price, s_price, s_per)
            # print("=" * 50)
        print(rank_li)
# Out:
# [ 메인 카테고리: ALL ]
# ['1', '2', '3', '4', '5']

# %%
res1 = requests.get('http://corners.gmarket.co.kr//Bestsellers?viewType=G&groupCode=G01')
soup1 = BeautifulSoup(res1.text, 'html.parser')

sub_path = "#subTabG01 > div > ul > li > a"
sub_lis = soup1.select(path1)

for li in sub_lis:
    sub_cate_url = main_url + li['href']
    sub_cate_title = li.text
    
    print(sub_cate_title, sub_cate_url)
# Out:
# 브랜드 여성의류 http://corners.gmarket.co.kr//Bestsellers?viewType=G&groupCode=G01&subGroupCode=S161
# 브랜드 남성의류 http://corners.gmarket.co.kr//Bestsellers?viewType=G&groupCode=G01&subGroupCode=S162
# 브랜드 진/캐쥬얼  http://corners.gmarket.co.kr//Bestsellers?viewType=G&groupCode=G01&subGroupCode=S163
# 여성의류 http://corners.gmarket.co.kr//Bestsellers?viewType=G&groupCode=G01&subGroupCode=S102
# 남성의류 http://corners.gmarket.co.kr//Bestsellers?viewType=G&groupCode=G01&subGroupCode=S002
# 언더웨어 http://corners.gmarket.co.kr//Bestsellers?viewType=G&groupCode=G01&subGroupCode=S088

# %%
sub_url = 'http://corners.gmarket.co.kr//Bestsellers?viewType=G&groupCode=G01&subGroupCode=S162'

prod_path = '#gBestWrap > div > div:nth-child(5) > div:nth-child(3) > ul > li'

res3 = requests.get(sub_url)
soup3 = BeautifulSoup(res3.text, 'html.parser')
lis = soup3.select(prod_path)

for li in lis:
    rank = li.select('p')[0].text
    prod_title = li.select('.itemname')[0].text
    old_price = li.select('.o-price')[0].text
    s_price = li.select('.s-price > strong > span')[0].text
    
    per = li.select('em')
    if per:
        s_per = per[0].text
    else:
        s_per = '0%'
    prod_url = li.select('div.thumb > a')[0]['href']

    print(rank, prod_title, prod_url, old_price, s_price, s_per)
    print("=" * 50)
# Out:
# 1 [폴햄][폴햄] 공용 경량점퍼 / 보아집업 5종택1 (PHB4JP1020 2020 2040 TC3 http://item.gmarket.co.kr/Item?goodscode=2345692742&ver=637799161754007621 28,000원 21,000원 25%
# ==================================================
# 2 [레노마셔츠]레노마 인기 긴소매 셔츠 모음전 http://item.gmarket.co.kr/Item?goodscode=2218978341&ver=637799161754007621 49,000원 30,000원 38%
# ==================================================
# 3 [헤지스]20+10% 헤지스남성 니트/티셔츠 外 발렌타인 선물BEST http://item.gmarket.co.kr/Item?goodscode=2099438427&ver=637799161754007621 239,000원 119,500원 50%
# ==================================================
# 4 [니]NII 봄 프리뷰 맨투맨/후드/집업외+쿠폰혜택 http://item.gmarket.co.kr/Item?goodscode=1652387921&ver=637799161754007621 35,800원 17,900원 50%
# ==================================================
# 5 [인디안]인디안 봄선오픈 정장SET  슈즈/넥타이/셔츠/팬츠외 http://item.gmarket.co.kr/Item?goodscode=1644625234&ver=637799161754007621 58,000원 29,000원 50%
# ==================================================
# 6 겨울쇼핑정복~ 데이리룩의 끝 TRUGEN 코트다운외 http://item.gmarket.co.kr/Item?goodscode=2122240258&ver=637799161754007621 132,900원 39,900원 69%
# ==================================================
# 7 [인디안]인디안 봄프리뷰+겨울시즌오프 니트/셔츠/정장셋업외 http://item.gmarket.co.kr/Item?goodscode=1632202735&ver=637799161754007621 76,800원 38,400원 50%
# ==================================================
# 8 [앤드지 바이 지오지아](신세계김해점)21FW 360 스트레치 사이드벤딩 슬림핏 슬랙스 팬츠 5종 택1[BZB4PP1101] http://item.gmarket.co.kr/Item?goodscode=2307470699&ver=637799161754007621 29,000원 21,970원 24%
# ==================================================
# 9 [올젠][올젠] 울 캐시미어 라운드넥 니트 ZPB4ER1502 http://item.gmarket.co.kr/Item?goodscode=2206899681&ver=637799161754007621 30,000원 22,200원 26%
# ==================================================
# 10 [에디션앤드지][에디션앤드지] 덕다운 카라 숏패딩 점퍼 4종 NEB4JP1901 http://item.gmarket.co.kr/Item?goodscode=2206152900&ver=637799161754007621 39,000원 29,250원 25%
# ==================================================
# 11 [파타고니아] P-6 라벨 업라이절 스웨트셔츠 기모 맨투맨 http://item.gmarket.co.kr/Item?goodscode=2313850260&ver=637799161754007621 36,800원 35,700원 2%
# ==================================================
# 12 [앤드지 바이 지오지아](신세계마산점)21FW 겨울바지 면바지 기모바지 치노팬츠 4종 택1 BZB4PP1103 http://item.gmarket.co.kr/Item?goodscode=2309712558&ver=637799161754007621 29,000원 21,970원 24%
# ==================================================
# 13 남녀공용 라운드넥 오가닉 꽈배기 니트 (5컬러)/ 타미힐피거. http://item.gmarket.co.kr/Item?goodscode=2331914121&ver=637799161754007621 54,900원 49,960원 8%
# ==================================================
# 14 21 F/W 캐시미어 100프로 라운드니트 4종택1(BZB4ER1701) http://item.gmarket.co.kr/Item?goodscode=2294154824&ver=637799161754007621 69,000원 49,680원 28%
# ==================================================
# 15 [앤드지 바이 지오지아](신세계타임스퀘어점패션관)21 FW 카라넥 경량 덕다운 리버시블 점퍼 2종 택 1 BZB4JP1101 http://item.gmarket.co.kr/Item?goodscode=2307470434&ver=637799161754007621 45,000원 36,340원 19%
# ==================================================
# 16 [에디션앤드지](신세계경기점)[에디션] 21FW 프리미엄다운 스텐에리 점퍼 4종택 1 [NEB4JP1902] http://item.gmarket.co.kr/Item?goodscode=2236827772&ver=637799161754007621 55,000원 41,670원 24%
# ==================================================
# 17 [앤드지 바이 지오지아][앤드지] 21 F/W 캐시미어 블렌드 라운드넥 풀오버 스웨터 5종택1 BZB4ER1101 http://item.gmarket.co.kr/Item?goodscode=2294237003&ver=637799161754007621 30,000원 23,400원 22%
# ==================================================
# 18 [엘르옴므]베스트 기모셔츠 가디건 긴소매셔츠 50종 http://item.gmarket.co.kr/Item?goodscode=2177290933&ver=637799161754007621 63,000원 18,900원 70%
# ==================================================
# 19 [그렉노먼]그렉노먼 21FW 신상 남성 구스 경량다운 http://item.gmarket.co.kr/Item?goodscode=2345396493&ver=637799161754007621  59,000원 0%
# ==================================================
# 20 [오스틴리드][by파크랜드] 정장/자켓/점퍼/코트 빅세일 (SET_FP_210720) http://item.gmarket.co.kr/Item?goodscode=2171034367&ver=637799161754007621  32,900원 0%
# ==================================================
# 21 [타미힐피거]20%쿠폰 타미 맨즈 시즌오프 ~30% 니트/티셔츠 http://item.gmarket.co.kr/Item?goodscode=2336790520&ver=637799161754007621 219,000원 153,300원 30%
# ==================================================
# 22 [앤드지 바이 지오지아][앤드지] ANDZ 21F/W 하이넥 구스다운코트 BLB4CP1001 1002 http://item.gmarket.co.kr/Item?goodscode=2253258345&ver=637799161754007621 59,000원 46,020원 22%
# ==================================================
# 23 [올젠]울 캐시미어 라운드넥 니트 ZPB4ER1502 http://item.gmarket.co.kr/Item?goodscode=2206203452&ver=637799161754007621 30,000원 20,100원 33%
# ==================================================
# 24 [올젠][올젠] 구스 씬다운 캐시미어 혼방 코트 http://item.gmarket.co.kr/Item?goodscode=2320673810&ver=637799161754007621 90,000원 63,000원 30%
# ==================================================
# 25 [레노마][레노마(남성)] F/W 프리미엄 시그니처 슬림스판 정장11종RLKMSJ11AJS http://item.gmarket.co.kr/Item?goodscode=2333209297&ver=637799161754007621 99,000원 69,300원 30%
# ==================================================
# 26 [폴햄][폴햄] 공용 알래스카 에어 프리미엄 푸퍼 점퍼 (PHZ4JP3220) http://item.gmarket.co.kr/Item?goodscode=2241689768&ver=637799161754007621 49,900원 37,430원 24%
# ==================================================
# 27 [폴햄]공용 3PACK+1 무지 반팔티셔츠(PHB5TR3900) http://item.gmarket.co.kr/Item?goodscode=2099996502&ver=637799161754007621 19,900원 15,730원 20%
# ==================================================
# 28 [란체티]남성 긴팔 와이셔츠 정장 드레스셔츠 모음 http://item.gmarket.co.kr/Item?goodscode=2216957169&ver=637799161754007621 42,000원 16,900원 59%
# ==================================================
# ==================================================
# 59 [올젠]프리즘 치노 팬츠_ZPB4PP1901 http://item.gmarket.co.kr/Item?goodscode=2298446200&ver=637799161754007621 99,000원 30,900원 68%
# ==================================================
# 60 [앤드지 바이 지오지아](신세계강남점)21 F/W 프리미엄 안감 퍼 구스 패딩점퍼 3종 택 1  BZB4FP1101HY http://item.gmarket.co.kr/Item?goodscode=2305689682&ver=637799161754007621 139,000원 112,250원 19%
# ==================================================
# 61 [레노마셔츠]갤러리아  품격있는  샐러리맨을 위한 21년FW 가을신상  특가전(RLFSL0104WH)외1 http://item.gmarket.co.kr/Item?goodscode=1755269193&ver=637799161754007621 30,000원 24,600원 18%
# ==================================================
# 62 [리얼지오지아](현대백화점)21 F/W 요요진 콜라보 기모 맨투맨 티셔츠 10가지 컬러 ADB4TR1902 http://item.gmarket.co.kr/Item?goodscode=2317035867&ver=637799161754007621 17,000원 15,300원 10%
# ==================================================
# 63 [올젠]캐시미어 라운드넥 스웨터_ZPB4ER1901 http://item.gmarket.co.kr/Item?goodscode=2298675476&ver=637799161754007621 99,000원 30,900원 68%
# ==================================================
# 64 [레노마][레노마(남성)] 레노마 FW 프리미엄 울캐시미어 겨울코트 5종 택1 RMLPBH57A58 http://item.gmarket.co.kr/Item?goodscode=2285060316&ver=637799161754007621 99,000원 78,210원 21%
# ==================================================
# 65 [올젠]F/W 인기 남성 패딩 아우터 모음 ZPB4CP1502 http://item.gmarket.co.kr/Item?goodscode=2252560246&ver=637799161754007621 90,000원 60,300원 33%
# ==================================================
# 66 [언더아머][언더아머_스포츠] 남성 UA 라이벌 테리 면팬츠 1361644-001 ASIM http://item.gmarket.co.kr/Item?goodscode=2012998211&ver=637799161754007621 41,300원 37,170원 10%
# ==================================================
# 67 [예작][대구백화점] [예작]21년 가을 슬림핏긴소매 16종 택1(YJ1FBS916 외) http://item.gmarket.co.kr/Item?goodscode=2244083769&ver=637799161754007621 33,000원 23,100원 30%
# ==================================================
# 68 [앤드지 바이 지오지아][앤드지] 21 f/w 캐시미어 블렌디드 체스터필드 코트 4종 택1 BLB4CG1001 http://item.gmarket.co.kr/Item?goodscode=2328538857&ver=637799161754007621 99,000원 73,260원 26%
# ==================================================
# 69 [지오지아][지오지아] [하프클럽/]솔리드 더블 롱 코트_AEB4CB1103BK http://item.gmarket.co.kr/Item?goodscode=2298396684&ver=637799161754007621 94,830원 90,090원 4%
# ==================================================
# 70 [앤드지 바이 지오지아](광주신세계)21FW 프리미엄  덕다운 푸퍼점퍼 2종택1 http://item.gmarket.co.kr/Item?goodscode=2273748503&ver=637799161754007621 79,000원 63,800원 19%
# ==================================================
# 71 [앤드지 바이 지오지아](광주신세계)21FW 리버서블 경량 덕다운 점퍼 3종 택1 [BLB4JP1001] http://item.gmarket.co.kr/Item?goodscode=2223829264&ver=637799161754007621 59,000원 47,650원 19%
# ==================================================
# 72 [에디션앤드지][에디션앤드지] 프리미엄 구스다운 패딩코트 5종 NEB4CP1901/2 http://item.gmarket.co.kr/Item?goodscode=2235577362&ver=637799161754007621 69,000원 55,200원 20%
# ==================================================
# 87 [테이트][테이트] 레귤러핏스판슬렉스KABW0-MPL060 http://item.gmarket.co.kr/Item?goodscode=2351188269&ver=637799161754007621  30,720원 0%
# ==================================================
# 88 [바쏘][바쏘옴므] [바쏘옴므] 신상FW 시베리아 구스다운 숏패딩 3컬러 (SETWSV4MU_HA) http://item.gmarket.co.kr/Item?goodscode=2300248071&ver=637799161754007621 111,250원 89,010원 19%
# ==================================================
# 89 [에스티듀퐁][듀퐁-남성셔츠] 새해신상 듀퐁 긴소매 PREMIUM 셔츠 슬림핏 10종 모음전 http://item.gmarket.co.kr/Item?goodscode=1633369366&ver=637799161754007621 49,000원 35,280원 28%
# ==================================================
# 90 (R지오지아) (신세계하남점)[지오지아] F/W 캐시미어 블랜디드 집업 가디건 2종 택1 (AAA4EC1102) http://item.gmarket.co.kr/Item?goodscode=2284230899&ver=637799161754007621 39,000원 31,200원 20%
# ==================================================
# 91 [리빌모아] 겨울 패브릭 기모안감 사방스판 허리밴드 캐쥬얼 정장바지 http://item.gmarket.co.kr/Item?goodscode=2282128581&ver=637799161754007621 29,800원 27,420원 7%
# ==================================================
# 92 [앤드지 바이 지오지아](신세계마산점)네이비컬러 오버핏조끼 패딩조끼 점퍼 BZB4VP1201 http://item.gmarket.co.kr/Item?goodscode=2307470298&ver=637799161754007621 77,000원 58,330원 24%
# ==================================================
# 93 [지오지아][지오지아] [하프클럽/]솔리드 더블 오버핏 롱 코트_AEB4CB1103 http://item.gmarket.co.kr/Item?goodscode=2336818979&ver=637799161754007621 94,830원 90,090원 4%
# ==================================================
# 94 [하프클럽/필골드]쟌피엘 남성 모직 체크 콤비 자켓 남자마이 JP752n754 http://item.gmarket.co.kr/Item?goodscode=2334953509&ver=637799161754007621  69,900원 0%
# ==================================================
# 95 [지오지아]지오지아 겨울세일 아우터/니트/맨투맨 外 http://item.gmarket.co.kr/Item?goodscode=2274833488&ver=637799161754007621 198,000원 99,000원 50%
# ==================================================
# 96 [르까프][르까프] 1219JD408 남성 배색 후드 헤비 중기장 덕다운 자켓 http://item.gmarket.co.kr/Item?goodscode=2276384782&ver=637799161754007621 35,900원 28,010원 21%
# ==================================================
# 97 [지오다노]남성 트렌치 오리털다운 패딩코트 070925 http://item.gmarket.co.kr/Item?goodscode=1968703299&ver=637799161754007621 65,000원 58,500원 10%
# ==================================================
# 98 (롯데백화점)21FW 박서준 캠핑자수 기모후드티 6종 ADB4TH1903 DJSA DJST DJSD http://item.gmarket.co.kr/Item?goodscode=2310081504&ver=637799161754007621 23,900원 19,120원 20%
# ==================================================
# 99 캐시미어 블렌드 텍스쳐드 스웨터 4종 택1(BZA4ER1201) http://item.gmarket.co.kr/Item?goodscode=2207622403&ver=637799161754007621 30,000원 21,600원 28%
# ==================================================
# 100 [앤드지 바이 지오지아]갤러리아  ANDZ 앤드지 21 F/W 아우터형 퀼팅 포켓 셔츠 4종1택모음 BZB4WC1102 http://item.gmarket.co.kr/Item?goodscode=2339238083&ver=637799161754007621 39,000원 29,640원 24%
# ==================================================
